# %% [markdown]
# # Daftar Kegiatan Praktikum 4 - RGB dan Grayscale
# 1. Percobaan 1 - Plot Histogram of Grayscale Image
# 2. Percobaan 2 - Plot Histogram of RGB Image
#
# ![image.png](attachment:044b0246-4f66-44ed-9eeb-a10839d82ce2.png)

# %% [markdown]
# # Import Library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.pyplot as plt
from skimage import data

# %% [markdown]
# # Load Image

# %%
from skimage.filters import threshold_minimum
from skimage.filters import threshold_mean
from skimage import io

# grayImage = data.camera()
# print('gray image shape : ',grayImage.shape)
grayImage = io.imread('/content/pemandangan.jpeg', as_gray=True)
print('gray image shape : ', grayImage.shape)

# rgbImage = data.astronaut()
# print('rgb image shape : ',rgbImage.shape)
rgbImage = io.imread('/content/pemandangan.jpeg')
print('rgb image shape : ', rgbImage.shape)
# Out:
# gray image shape :  (667, 500)
# rgb image shape :  (667, 500, 3)

# %% [markdown]
# # Percobaan 1 - Plot Histogram of Grayscale Image

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 12))
ax = axes.ravel()

ax[0].imshow(grayImage, cmap=plt.cm.gray)
ax[0].set_title("Grayscale Image")
ax[1].hist(grayImage.ravel(), bins=256)
ax[1].set_title('Histogram')

plt.tight_layout()

# %% [markdown]
# # # Percobaan 2 - Plot Histogram of RGB Image

# %%
red = rgbImage[:,:,0]
green = rgbImage[:,:,1]
blue = rgbImage[:,:,2]

print('Red Shape = ',red.shape)
print('Green Shape = ',green.shape)
print('Blue Shape = ',blue.shape)

fig, axes = plt.subplots(3, 3, figsize=(12, 12))
ax = axes.ravel()

ax[3].imshow(rgbImage)
ax[3].set_title("Original")

ax[1].imshow(red, cmap=plt.cm.gray)
ax[1].set_title("Red Channel")
ax[2].hist(red.ravel(), bins=256)
ax[2].set_title('Histogram')

ax[4].imshow(green, cmap=plt.cm.gray)
ax[4].set_title("Green Channel")
ax[5].hist(green.ravel(), bins=256)
ax[5].set_title('Histogram')

ax[7].imshow(blue, cmap=plt.cm.gray)
ax[7].set_title("Blue Channel")
ax[8].hist(blue.ravel(), bins=256)
ax[8].set_title('Histogram')

fig.tight_layout()
plt.show()
# Out:
# Red Shape =  (667, 500)
# Green Shape =  (667, 500)
# Blue Shape =  (667, 500)

# %%
# !git clone https://github.com/amad-dong/Praktikum-Pengolohan-Citra-Digital-Python.git
# Out:
# Cloning into 'Praktikum-Pengolohan-Citra-Digital-Python'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 183 (delta 75), reused 126 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (183/183), 16.04 MiB | 22.78 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
